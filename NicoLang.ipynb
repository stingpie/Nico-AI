# %% [markdown]
# This is a combination of a time-compressing VAE and a SDAPM module. Training is split into three sets:
#
# 1) text to text VAE training (reconstruction)
#
# 2) vec 2 vec SDAPM training (prediction)
#
# 3) text to text SDAPM training. (prediction)
#
# set 1 only involves the VAE, set 2 only involves the encoder & SDAPM, set 3 involves all modules, but the VAE is frozen.

# %%
''' Psuedo code

import SDPAM
import VAE

import dataset
dataset.load("gutenberg conversations")
import tokenizers
tokenizers.load('unigram_25600.json')


sdapm = SDAPM(data_width)
vae = VAE(data_width)


iters=0
while true:
  if(iters%30 < 10):
    data = tokenize(load_conv())
    reconstruction, t_loss, kl_loss = vae(data)
    loss = cross_entropy(reconstruction, data) + t_loss + kl_loss
    loss.backward()
    opt.step()
  elif(iters%30>20):
    data = tokenize(load_conv())
    vae.decoder.freeze()
    prediction, splits = vae.decode(sdapm(vae.encode(data)[:-1].detach()))
    loss = cross_entropy(prediction, data[splits[0]:])
    loss.backward()
    opt.step()
    vae.decoder.unfreeze()

  else:
    data = tokenize(load_conv())
    enc_data = vae.encode(data).detach()
    prediction = sdapm(enc_data[:-1], enc_data[1:])
    loss = mse_loss(prediction, enc_data[1:])
    loss.backward()
    opt.step()

  print(loss)


'''
# Out:
# ' Psuedo code\n\nimport SDPAM\nimport VAE\n\nimport dataset\ndataset.load("gutenberg conversations")\nimport tokenizers\ntokenizers.load(\'unigram_25600.json\')\n\n\nsdapm = SDAPM(data_width)\nvae = VAE(data_width)\n\n\niters=0\nwhile true:\n  if(iters%30 < 10):\n    data = tokenize(load_conv())\n    reconstruction, t_loss, kl_loss = vae(data)\n    loss = cross_entropy(reconstruction, data) + t_loss + kl_loss\n    loss.backward()\n    opt.step()\n  elif(iters%30>20):\n    data = tokenize(load_conv())\n    vae.decoder.freeze()\n    prediction, splits = vae.decode(sdapm(vae.encode(data)[:-1].detach()))\n    loss = cross_entropy(prediction, data[splits[0]:])\n    loss.backward()\n    opt.step()\n    vae.decoder.unfreeze()\n\n  else:\n    data = tokenize(load_conv())\n    enc_data = vae.encode(data).detach()\n    prediction = sdapm(enc_data[:-1], enc_data[1:])\n    loss = mse_loss(prediction, enc_data[1:])\n    loss.backward()\n    opt.step()\n\n  print(loss)\n\n\n'

# %%
# !pip install -U datasets
# !pip install torch-optimizer
# !pip install tensordict
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.33.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.11/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from torch-optimizer) (2.6.0+cu124)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.5.0->torch-optimizer) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.5.0->torch-optimizer) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.5.0->torch-optimizer) (3.0.2)
# Requirement already satisfied: tensordict in /usr/local/lib/python3.11/dist-packages (0.9.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from tensordict) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensordict) (2.0.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from tensordict) (3.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensordict) (25.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from tensordict) (8.7.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from tensordict) (3.11.0)
# Requirement already satisfied: pyvers<0.2.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from tensordict) (0.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->tensordict) (3.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->tensordict) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->tensordict) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->tensordict) (3.0.2)

# %%
import torch as T
import torch.nn.functional as F
import os


if not os.path.exists("gutenberg_conv.json"):
  from datasets import load_dataset
  ds = load_dataset("willwade/Gutenberg-dialog-en")

  ds.set_format("torch")

  import json
  print(ds['train']['text'][:10])
  data = ("`GO`"+("`STOP`\n`GO`".join(ds['train']['text']))+"`STOP`").split("\n`GO``STOP`\n")
  with open("gutenberg_conv.json","w") as f:
    json.dump(data, f)
  print(data[0])
else:
  import json
  with open("gutenberg_conv.json",'r') as f:
    data  = json.load(f)
  print(data[0])

from tokenizers import Tokenizer
from tokenizers.models import Unigram
from tokenizers.trainers import UnigramTrainer
import tokenizers

vocab_size = 6400

if not os.path.exists("unigram-"+str(vocab_size)+".json"):


  import tokenizers.normalizers as nz

  tokenizer = Tokenizer(Unigram())
  tokenizer.normalizer=nz.Lowercase()

  import tokenizers.pre_tokenizers as pretok
  tokenizer.pre_tokenizer = pretok.Sequence([pretok.Digits(), pretok.Split(tokenizers.Regex("[\s,.:;'\"-=+_~{}\[\]<>?!@#$%^&*()|]"), 'isolated')])

  trainer = UnigramTrainer(vocab_size=vocab_size, unk_token="`UNK`", special_tokens=["`UNK`","`GO`", "`PAD`", "`STOP`"])
  print("training... (tokenizer)")
  import random
  tokenizer.train_from_iterator(random.sample(data,10_000), trainer)

  tokenizer.save("unigram-"+str(vocab_size)+".json")
else:
  tokenizer = Tokenizer.from_file("unigram-"+str(vocab_size)+".json")


if not os.path.exists("tokenized_set.pkl"):
  print("tokenizing...")
  import random
  dataset = tokenizer.encode_batch(random.sample(data, len(data)//2))
  with open("tokenized_set.pkl", 'wb') as f:
    import pickle
    pickle.dump(dataset, f)
else:
  import pickle
  dataset = pickle.load(open("tokenized_set.pkl",'rb') )
print(dataset[0].tokens)
# Out:
# `GO`the shelling from the enemys mortars was severe . . . and having but little mortar powder we were unable to reply effectually . . . . i regret that our ordnance supplies are so scanty . . . . no powder for the mortars no suitable fuses for the fire on charleston no shells for the 30pounder parrotts a most useful gun for silencing the enemys fire no material for making cartridge bags or grease for lubricating the projectiles . . . . more ammunition for the 300pounder the most useful guns in these works is also very much needed . . . .`STOP`
# `GO`within the last 2 days the work . . . has been greatly interfered with by a corps of sharpshooters . . . stationed on fort sumter . the bullets came in very thick when i was at the front this morning . . . .`STOP`
# ['`GO`', 'my', ' ', 'dear', ' ', 'simon', ' ', 'you', ' ', 'have', ' ', 'behaved', ' ', 'i', 'r', 'reproach', 'ably', ' ', '.', ' ', 'eleanor', ' ', 'will', ' ', 'feel', ' ', 'it', ' ', 'for', ' ', 'some', ' ', 'time', ' ', 'no', ' ', 'doubt', ' ', 'but', ' ', 'she', ' ', 'is', ' ', 'young', ' ', 'and', ' ', 'will', ' ', 'soon', ' ', 'get', ' ', 'over', ' ', 'it', ' ', '.', ' ', 'i', ' ', "'", 'll', ' ', 'send', ' ', 'her', ' ', 'to', ' ', 'the', ' ', 'dr', 'as', 'com', 'be', 'pry', 'n', 'ne', 's', ' ', 'in', ' ', 'paris', ' ', '.', ' ', 'and', ' ', 'as', ' ', 'for', ' ', 'yourself', ' ', 'your', ' ', 'terrible', ' ', 'misfortune', ' ', 'will', ' ', 'be', ' ', 'as', ' ', 'much', ' ', 'as', ' ', 'you', ' ', 'can', ' ', 'bear', ' ', '.', ' ', 'you', ' ', 'must', ' ', 'n', "'", 't', ' ', 'increase', ' ', 'it', ' ', 'by', ' ', 'any', ' ', 'worries', ' ', 'on', ' ', 'her', ' ', 'be', 'half', ' ', '.', ' ', 'in', ' ', 'that', ' ', 'way', ' ', 'i', ' ', "'", 'll', ' ', 'do', ' ', 'my', ' ', 'utmos', 't', ' ', 'to', ' ', 'help', ' ', 'you', ' ', '.', '`STOP`', '\n', '`GO`', 'you', ' ', 'are', ' ', 'kindness', ' ', 'itself', ' ', 'mr', 's', ' ', '.', ' ', 'f', 'a', 'ver', 's', 'ham', '`STOP`']

# %%
# modified from https://avandekleut.github.io/vae/
import math

class PositionalEncoding(T.nn.Module):

    def __init__(self, d_model: int, dropout: float = 0.1, max_len: int = 5000, device='cpu'):
        super().__init__()
        self.device=device
        self.dropout = T.nn.Dropout(p=dropout)

        position = T.arange(max_len, device=self.device).unsqueeze(1)
        div_term = T.exp(T.arange(0, d_model, 2, device=self.device) * (-math.log(10000.0) / d_model))
        pe = T.zeros((max_len, 1, d_model), device=self.device)
        pe[:, 0, 0::2] = T.sin(position * div_term)
        pe[:, 0, 1::2] = T.cos(position * div_term)
        self.register_buffer('pe', pe)

    def forward(self, x):
        """
        Arguments:
            x: Tensor, shape ``[batch_size, seq_len, embedding_dim]``
        """
        x= x.transpose(0,1)
        x = x + self.pe[:x.size(0)]
        return self.dropout(x).transpose(0,1)


def drop_tokens(x, probability):
    return x * T.where(T.rand(x.size()[:-1],device=x.device)>probability,0,1).unsqueeze(-1)

def direction(x):
    return T.round(T.clamp(x, min=-1, max=1))

def deNaNed(x):
    return T.where(T.isnan(x),0,x)

def max_norm(x, max):
  return T.where(T.sum(x)>max, F.normalize(x, p=1, dim=-1)*max, x)

class BernoulliMix(T.nn.Module):
  def __init__(self, mix_ratio=0.5, device='cpu'):
    super().__init__()
    self.device=device
    self.B = T.distributions.Bernoulli(probs=mix_ratio)
    if(isinstance(device, str) and "cuda" in device):
      self.B.probs = self.B.probs.cuda()

  def set_probs(self, probs):
    self.B = T.distributions.Bernoulli(probs=probs)
    if(isinstance(self.device, str) and "cuda" in self.device):
      self.B.probs = self.B.probs.cuda()

  def forward(self, a, b):

    if(self.training):
      return T.where(self.B.sample(a.size()).bool(), a, b)
    else:
      return a

def softabs(x,k):
  return (x**2)/(k+T.abs(x))



class TVET(T.nn.Module): # transformer variational encoder across time dimension.
    def __init__(self, data_width, emb_size=None,  temporal_division=8, layer_num=3, nheads = 6, device='cpu'):
        super().__init__()
        self.device=device
        self.emb_size = emb_size if emb_size!=None else data_width
        self.layers = [T.nn.TransformerEncoderLayer(data_width, nheads, dim_feedforward=data_width, batch_first=True, device=self.device )]*(layer_num-1)
        self.expansion = T.nn.Linear(data_width, self.emb_size*2, device=self.device)
        print(emb_size*2)
        self.var_layer = T.nn.TransformerEncoderLayer(self.emb_size*2, nheads, dim_feedforward=data_width*2, batch_first=True, device=self.device)
        self.poscoder = PositionalEncoding(data_width, max_len=10_000, device=self.device)

        self.expansion_offset=0

        self.temporal_division = temporal_division


        self.N = T.distributions.Normal(0, 1)
        if(isinstance(device, str) and "cuda" in device):
            self.N.loc = self.N.loc.cuda() # hack to get sampling on the GPU
            self.N.scale = self.N.scale.cuda()
        self.kl = 0

    def forward(self, x):
        x = self.poscoder(x)

        for layer in self.layers:
            x = layer(x, src_mask = T.nn.Transformer.generate_square_subsequent_mask(x.size(1)), is_causal=True) + x
        x = self.expansion(x)
        x = self.var_layer(x, src_mask = T.nn.Transformer.generate_square_subsequent_mask(x.size(1)), is_causal=True)



        #x = T.sum(T.stack(T.split(x,temporal_division,dim=-1),dim=-1),dim=-1) ## chunk along the time dimension(adding a new dimension) then sum along the new dimension.
        mu =  T.chunk(x,2,dim=-1)[0]
        sigma = T.exp(T.chunk(x,2,dim=-1)[1])
        z = mu + (sigma*self.N.sample(mu.shape) if self.training else 0)
        self.kl = (sigma**2 + mu**2 - T.log(sigma) - 1/2).sum()

        ## This is a craZy way to implement variable compression lengths.
        ## I would much prefer a scan operator, but we aren't allowed nice things.

        reshaped = z[:,:,-1].unsqueeze(-1).expand(-1,-1,z.size(-2))

        reshaped = deNaNed(F.sigmoid(self.expansion_offset+z[:,:,-1].unsqueeze(-2).expand(-1, z.size(-2), -1)))+0.01 ## the +100 is a hack to ecnourage little compression at the beginning.
        sections = T.clamp(T.sum(T.tril(T.clamp(reshaped,max=1)),dim=-1)-1e-6, min=0)
        #sections = F.relu(T.where(sections[:,0].unsqueeze(-1)>=1, sections-1, sections))


        len_loss = softabs(T.amax(sections,dim=-1)-(x.size(1)/self.temporal_division), 1/3) ##punish lengths above len/temporal_div


        densified_z = T.zeros(  ( z.size(0), int(T.amax(T.ceil(sections)).item()), z.size(-1) ) , device=self.device)
        for i in range(x.size(0)):
            #print("??")
            ## Writen in pytorch 2.5 (apparently, this API may change in the future. )

            densified_z[i,T.floor(sections).int()] = T.index_reduce(z, dim=1, index=T.floor(sections[i]).int(), source=z, reduce='mean')
        ##
        return densified_z, len_loss, sections


class TVDT(T.nn.Module): # transformer variational encoder across time dimension.
    def __init__(self, data_width, emb_size=None,  temporal_division=8, layer_num=3, nheads = 6, device='cpu'):
        super().__init__()


        self.device=device
        self.nheads = nheads
        self.emb_size= emb_size if emb_size != None else data_width
        self.layers = [T.nn.TransformerEncoderLayer(data_width, nheads, dim_feedforward=data_width, batch_first=True, device=self.device )]*layer_num
        self.poscoder = PositionalEncoding(data_width, max_len=10_000, device=self.device)
        self.b_mix = BernoulliMix(0.5, device=self.device)


    def forward(self, z, skip_vec=None):

        z = self.poscoder(z)

        for i in range(len(self.layers)):
            layer=self.layers[i]

            #print("??2")
            if(i==len(self.layers)//2 and skip_vec!=None and self.training): ## mix in 'correct' answer at the middle layer
              z = layer(self.b_mix(z, skip_vec), src_mask = T.nn.Transformer.generate_square_subsequent_mask(z.size(1), device=self.device)) + z
            else:
              z = layer(z, src_mask = T.nn.Transformer.generate_square_subsequent_mask(z.size(1), device=self.device)) + z
        return z

class TVAT(T.nn.Module):
    def __init__(self, data_width, emb_size=None, temporal_division=8, layer_num=12, nheads=12, device='cpu'):
        super().__init__()
        self.device=device
        self.emb_size = emb_size if emb_size!=None else data_width
        self.encoder = TVET(data_width, emb_size, temporal_division, math.ceil(layer_num/2), nheads, device=self.device)
        self.decoder = TVDT(data_width, emb_size, temporal_division, math.floor(layer_num/2)+1, nheads, device=self.device)
        self.dropout = T.nn.Dropout()
        self.proj_up = T.nn.Linear(self.emb_size, data_width, device=self.device)
        self.kl=0



    def generate_mask(self, z, length, return_sizes=False):
      idxs=[0]*z.size(0)
      for i in range(z.size(0)):
          idxs[i] = T.repeat_interleave(T.clamp((1/(F.sigmoid(z[i,:,-1])+0.01)),max=length).int())[:length]

      #idxs = T.stack(idxs, dim=0)
      target_mask = T.full((z.size(0), length,length), -float('inf'), device=self.device)
      sizes=[None]*z.size(0)
      for i in range(z.size(0)): ###AAAAHHHH I HATE THISSS
        sizes[i] = T.histc(idxs[i].float(), T.clamp(T.amax(idxs[i]),min=1)   ).int().tolist()

        xpos = 0
        ypos = sizes[i][0]

        for j in range(len(sizes[i])-1):
          target_mask[i,xpos:xpos+sizes[i][j],ypos:]=0
          ypos+=sizes[i][j+1]
          xpos+=sizes[i][j]
      target_mask = target_mask.mT

      if(return_sizes):
        return target_mask, sizes
      else:
        return target_mask

    def encode(self, x, return_mask=False):
        result, len_loss, sections = self.encoder(x)
        self.kl = self.encoder.kl

        return result, len_loss, sections


    def decode(self, x, length, z=None):

        expanded_z = T.zeros((x.size(0), length, self.emb_size), device=self.device)
        idxs=[0]*x.size(0)
        for i in range(x.size(0)):
            sizes = max_norm(T.clamp((1/(F.sigmoid(x[i,:,-1])+0.01)),max=x.size(1) ), x.size(1)*1.2)
            idxs[i] = T.repeat_interleave(sizes.int())[:length]
            expanded_z[i,:min(length,idxs[i].size(-1))] = x[i,idxs[i]][:length]
        '''
        #idxs = T.stack(idxs, dim=0)
        target_mask = T.full((x.size(0), x.size(-2),x.size(-2)), -float('inf'), device=self.device)

        for i in range(x.size(0)): ###AAAAHHHH I HATE THISSS
          #print(T.amax(idxs[i]))i
          sizes = T.histc(idxs[i].float(), T.clamp(T.amax(idxs[i]),min=1)    ).int().tolist()

          xpos = 0
          ypos = sizes[0]

          for j in range(len(sizes)-1):
            target_mask[i,xpos:xpos+sizes[j],ypos:]=0
            ypos+=sizes[j+1]
            xpos+=sizes[j]
        target_mask = target_mask.mT

        '''

        result = self.decoder(self.proj_up(expanded_z), z)
        mask = T.zeros((x.size(0), length), device=self.device).unsqueeze(-1)
        for i in range(x.size(0)):
            mask[i,:idxs[i].size(-1)]=1
        return mask * result




    def forward(self, x):
        z, len_loss, sections = self.encoder(x)
        self.kl = self.encoder.kl
        #print(T.mean(T.amax(sections,dim=-1)).item())

        expanded_z = T.zeros((x.size(0), x.size(1), self.emb_size), device=self.device)
        idxs=[0]*x.size(0)
        for i in range(x.size(0)):
            sizes = max_norm(T.clamp((1/(F.sigmoid(z[i,:,-1])+0.01)),max=x.size(1) ), x.size(1)*1.2)

            idxs[i] = T.repeat_interleave(sizes.int())[:x.size(1)]
            expanded_z[i,:min(x.size(1),idxs[i].size(-1))] = z[i,idxs[i]][:x.size(1)]
        '''
        #idxs = T.stack(idxs, dim=0)
        target_mask = T.full((x.size(0), x.size(-2),x.size(-2)), -float('inf'), device=self.device)

        for i in range(x.size(0)): ###AAAAHHHH I HATE THISSS
          sizes = T.histc(idxs[i].float(), T.clamp(T.amax(idxs[i]),min=1)   ).int().tolist()

          xpos = 0
          ypos = sizes[0]

          for j in range(len(sizes)-1):
            target_mask[i,xpos:xpos+sizes[j],ypos:]=0
            ypos+=sizes[j+1]
            xpos+=sizes[j]
        target_mask = target_mask.mT

        '''

        result = self.decoder(self.proj_up(expanded_z), self.decoder.poscoder(x))
        mask = T.zeros(x.size()[:-1], device=self.device).unsqueeze(-1)
        for i in range(x.size(0)):
            mask[i,:idxs[i].size(-1)]=1
        return mask * result, len_loss

# %%
from torch.nn.attention import SDPBackend, sdpa_kernel

class LanguageModel(T.nn.Module):

    def __init__(self, data_width, emb_size, vocab_size=12800, temporal_division=8,  device='cpu'):
        super().__init__()

        self.device=device

        self.embedding = T.nn.Embedding(vocab_size, data_width, device=self.device)
        self.tvat = TVAT(data_width, emb_size = emb_size, temporal_division = temporal_division, device=self.device)
        self.exbedding = T.nn.Linear(data_width, vocab_size, device=self.device)
        self.kl=0


        opt = T.optim.Adam(list([*self.embedding.parameters(), *self.exbedding.parameters()]))
        for i in range(0):
            F.cross_entropy(self.exbedding(self.embedding(T.arange(vocab_size, device=self.device))), T.diag(T.ones(vocab_size,device=self.device))).backward()
            opt.step()


    def forward(self, x):
        with sdpa_kernel(SDPBackend.MATH):
            #print(":D")
            decoded, loss = self.tvat(self.embedding(x))
            self.kl = self.tvat.kl
            mask = T.where(T.sum(T.abs(decoded), dim=-1,keepdim=True)==0,0,1)


            # technique to lessen repetitive outputs
            #hist_mask = T.zeros((x.size(1),x.size(1)),device=self.device)
            #for i in range(10):
            #    hist_mask = T.diagonal_scatter(hist_mask, T.ones(x.size(1)-i-1,device=self.device)/(2**i), offset=-1-i)
            #decoded -= T.sum(decoded.unsqueeze(-2).expand(-1,-1,x.size(1),-1) * (hist_mask.flip((1,)).reshape(1,x.size(1),x.size(1),1)), dim=-2)*0.5


            return mask*self.exbedding(decoded), loss

    def embed(self, x):
        with sdpa_kernel(SDPBackend.MATH):
            result, len_loss, sections =  self.tvat.encode(self.embedding(x))
            self.kl = self.tvat.kl
            return result, len_loss, sections

    def exbed(self, x, len, correct=None):
        with sdpa_kernel(SDPBackend.MATH):
            result = self.tvat.decode(x, len, z=correct)
            return self.exbedding(result)

# %%
# automatic procedural memory
import torch as T
import torch.nn.functional as F
#import tensordict
import math, random

## altered from mitm4 to use a transformer as worth estimator.

@T.no_grad()
def pos_encoding(data_width, index):

    mult = 2**T.arange(data_width)
    sins = T.sign(T.sin(index* 2**T.arange(data_width//2)))
    coss = T.sign(T.cos(index * 2**T.arange(data_width//2)))

    return T.cat((sins,coss),dim=-1)



def softswish(x): ## an activation function similar to swish.
    b = 0.2974953
    return T.where(x>20,x-0.944031344, (1/b)* T.log(1+T.exp(b*x))*(x/(1+T.abs(x))))

def tapered_swish(x):
    softsign =(lambda x_: x_/(1+T.abs(x_)))
    return softsign(x)*(softsign(x+1)+1)



class SDAPM(T.nn.Module):

    def __init__(self, data_width, max_steps=10, mem_len=100, layer_gain=None, var_lr=False, param_mem_mats=False, autoscale=True, sparse_router='top 3', router_search = False, device = 'cpu'):

        super().__init__()

        self.device = device
        self.data_width = data_width
        self.max_steps = max_steps
        self.mem_len = mem_len

        if layer_gain==None:
            layer_gain=1/data_width
        self.layer_gain=layer_gain

        self.memories=None  ## I'm using both tensordict and nested tensors for this. Tensordict allows me to cleanly modify memories using a single index, and nested tensor allows for the addition of more memories as time goes on, without overwriting existing tensors.
        self.autoscale=autoscale
        atten_dat_size= data_width*9+1 + 2*int(math.ceil(math.sqrt(mem_len)))

        self.num_attn_heads=6
        self.attention_model = T.nn.TransformerEncoder(T.nn.TransformerEncoderLayer(math.ceil(atten_dat_size/self.num_attn_heads)*self.num_attn_heads, self.num_attn_heads, dim_feedforward=atten_dat_size, batch_first=True, device=self.device), 4)

        #self.worth_model = T.nn.LSTM(data_width*2, data_width*2*4, num_layers=3,  batch_first=True, device=self.device)
        self.worth_model = T.nn.LSTM(data_width*2, data_width*2*4, num_layers=3, batch_first=True, device=self.device)
        self.hx_cx = None

        self.initial_mem_mats = layer_gain*T.eye(self.data_width, device=self.device).expand(mem_len,-1,-1)+0.001*(2*T.rand((mem_len, data_width,data_width), device=self.device)-1)

        for i in range(self.mem_len):
            permutations = T.randperm(self.data_width)
            self.initial_mem_mats[i] = self.initial_mem_mats[i,permutations]
            self.initial_mem_mats[i]*=T.sign(T.rand((self.data_width,self.data_width),device=self.device)-0.5)

        self.initial_bv = T.zeros((mem_len,data_width), device=self.device)
        self.initial_bw = T.zeros((mem_len,data_width), device=self.device)
        self.initial_worth = T.zeros((mem_len,1), device=self.device)
        self.initial_write_time = T.zeros((mem_len, int(math.ceil(math.sqrt(mem_len)))), device=self.device)

        if(param_mem_mats):
            self.initial_mem_mats = T.nn.Parameter(self.initial_mem_mats)
            self.initial_bv = T.nn.Parameter(self.initial_bv)
            self.initial_bw = T.nn.Parameter(self.initial_bw)
            self.initial_worth = T.nn.Parameter(self.initial_worth)
            self.initial_write_time=T.nn.Parameter(self.initial_write_time)
        #self.initial_mem_mats[::2]=T.round(T.rand((mem_len//2,data_width,data_width),device=self.device)-0.5)





        #self.initial_mem_mats[0]=T.eye(self.data_width,device=self.device)
        #self.initial_mem_mats[1] = T.flip(T.eye(data_width,device=self.device),dims=(-1,))
        #self.initial_bv[0] = T.zeros(data_width,device=self.device)
        #self.initial_bw[0] = T.zeros(data_width,device=self.device)


        self.worth_mult=1

        self.attn_activation = (lambda x: x)#self.deNaNed(F.normalize(x**3,dim=-2)))# T.where(x.abs()-x.abs().mean(dim=-2,keepdim=True)>0, x, 0))


        #self.activation = (lambda x: x)#x/(1+T.abs(x)))
        #self.inv_activation = (lambda x: x)#T.clamp(x,min=-0.999,max=0.999)/(1-T.abs(T.clamp(x,min=-0.999,max=0.999))))

        #self.activation = (lambda x: x/(1+T.abs(x)))
        #self.inv_activation = (lambda x: T.clamp(x,min=-0.999,max=0.999)/(1-T.abs(T.clamp(x,min=-0.999,max=0.999))))

        self.lstm_activation = (lambda x: T.clamp(x,min=-0.99999,max=0.99999)/(1-T.abs(T.clamp(x,min=-0.99999,max=0.99999))))

        #self.activation = (lambda x: T.sign(x)*T.log(T.abs(x)+1))
        #self.inv_activation = (lambda x: T.sign(x)*(T.exp(T.abs(x))-1))

        #self.activation = softswish # self-normalizing (ish)

        self.activation = tapered_swish

        self.just_reset=True
        self.steps_since_reset=0




    def engram_info(self):
        bv = self.memories[self.steps_since_reset]['bv']
        bw = self.memories[self.steps_since_reset]['bw']
        worth = self.memories[self.steps_since_reset]['w']
        diag = T.diagonal(self.memories[self.steps_since_reset]['m'],dim1=-1,dim2=-2)
        antidiag = T.diagonal(T.flip(self.memories[self.steps_since_reset]['m'],dims=(-1,)),dim1=-1,dim2=-2)
        top = self.memories[self.steps_since_reset]['m'][:,:,:,0]
        bottom = self.memories[self.steps_since_reset]['m'][:,:,:,-1]
        left = self.memories[self.steps_since_reset]['m'][:,:,0,:]
        right = self.memories[self.steps_since_reset]['m'][:,:,-1,:]
        write_time = self.memories[self.steps_since_reset]['t'].to(self.device)
        current_time = self.pos_encoding(self.steps_since_reset).unsqueeze(0).unsqueeze(-2).expand(bv.size(0), bv.size(1),-1).to(self.device)

        atten_dat_size= self.data_width*9+1 + 2*int(math.ceil(math.sqrt(self.mem_len)))
        zero_padding = T.zeros((self.memories[self.steps_since_reset]['m'].size(0), self.mem_len, math.ceil(atten_dat_size/self.num_attn_heads)*self.num_attn_heads - atten_dat_size), device=self.device)


        return T.cat((bv, bw, worth, diag, antidiag, top, bottom, left, right, write_time, current_time, zero_padding), dim=-1)


    def reset(self, x):
        self.memories=[{
                'm':self.initial_mem_mats.unsqueeze(0).expand(x.size(0),-1,-1,-1).clone(),
                'bv':self.initial_bv.unsqueeze(0).expand(x.size(0),-1,-1).clone(),
                'bw':self.initial_bw.unsqueeze(0).expand(x.size(0),-1,-1).clone(),
                'w':self.initial_worth.unsqueeze(0).expand(x.size(0),-1,-1).clone(),
                't':self.initial_write_time.unsqueeze(0).expand(x.size(0),-1,-1).clone()
                }]
        temp = {
            'm':T.empty((x.size(0), self.mem_len, self.data_width, self.data_width), device=self.device),
            'bv':T.empty((x.size(0), self.mem_len, self.data_width), device=self.device),
            'bw':T.empty((x.size(0), self.mem_len, self.data_width), device=self.device),
            'w':T.empty((x.size(0), self.mem_len, 1), device=self.device),
            't':T.empty((x.size(0), self.mem_len, int(math.ceil(math.sqrt(self.mem_len)))), device=self.device)
            }
        self.memories= self.memories*2 + [temp]*(x.size(-2)+1)
        self.steps_since_reset=0
        self.hx_cx = (T.zeros((3,x.size(0),self.data_width*2*4), device=self.device), T.zeros((3,x.size(0),self.data_width*2*4), device=self.device))

    def deNaNed(self, x):
        if(isinstance(x, dict)):
            for key in x.keys():

                x[key] = T.where(x[key].isnan(), T.rand(x[key].size(),device=self.device)*0.02-0.01, x[key])
                x[key] = T.where(x[key].isposinf(), 1_000_000, x[key])
                x[key] = T.where(x[key].isneginf(), -1_000_000, x[key])
            return x
        else:
            x = T.where(x.isnan(), T.rand(x.size(),device=self.device)*0.02-0.01, x)
            x = T.where(x.isposinf(), 1_000_000, x)
            x = T.where(x.isneginf(), -1_000_000, x)
            return x

    # adapted from https://en.wikipedia.org/wiki/Gray_code#Converting_to_and_from_Gray_code
    @T.no_grad()
    def pos_encoding(self, index):
        data_width = int(math.ceil(math.sqrt(self.mem_len)))
        mult = 2**(T.arange(data_width//2, device=self.device)-2)
        sins = T.sign(T.sin(index * mult))
        coss = T.sign(T.cos(index * mult))

        return T.cat((sins,coss),dim=-1)



    def sparsity(self, x):  ## uses the Hoyer measure. Gini would be invariant under cloning, but Gini requires
                            ## that the data is sorted.
        return ((self.data_width**0.5) - (T.sum(x,dim=-1)/T.sum(x**2,dim=-1 )))*(((self.data_width**0.5)-1)**-1)


    def forward(self,x, correct=None, reset=True):
        if(reset):
            self.reset(x)

        if correct!=None:
                loops = x.size(-2)
                results = T.empty(x.size(), device=self.device)
                routing_losses = [T.empty(1, device=self.device)]*loops

                for i in range(loops):
                    self.steps_since_reset+=1
                    ## changes to main memory are returned as a tuple of (engrams, memory_mask).
                    ## Engrams & memory mask have the same length as memory, and memory_mask
                    ## has masks for each key/attribute of the engram. Once all changes are decided,
                    ## the memory masks are multiplied by the engram, summed together,  and then
                    ## LERP'ed into the next memory step.

                    result, routing_loss, read_mem = self.read(x[:,i], correct[:,i])


                    if(self.autoscale): ## rescale to size of correct output
                      shift = T.mean(correct[:,i], dim=-1, keepdim=True) - T.mean(result, dim=-1, keepdim=True)
                      scale = T.amax(correct[:,i],dim=-1, keepdim=True) - T.amin(correct[:,i],dim=-1, keepdim=True)
                      result = F.normalize(result-shift,dim=-1, p=float('inf'))*scale #result * (T.linalg.vector_norm(correct[:,i], ord=1)/T.linalg.vector_norm(result, ord=1))

                    results[:,i]=result
                    routing_losses[i]+=routing_loss



                    consolidate_mem = self.consolidate(5,2) ## merge some memories together.

                    inaccuracy = T.mean(F.mse_loss(result, correct[:,i], reduction='none'), dim=-1,keepdim=True) ## TODO: add hook

                    memorize_mem = self.memorize(x[:,i],  correct[:,i], log_inaccuracy=T.log(inaccuracy+1e-6))


                    new_mem = {} ## Note: might need to make tensordict.

                    for key in self.memories[self.steps_since_reset].keys():
                        mask_sum = T.clamp(read_mem[1][key] + consolidate_mem[1][key] + memorize_mem[1][key],min=1e-6)
                        #if(key=='m'):
                            #print(mask_sum[0,:,0,0])


                        new_mem[key] = self.deNaNed((read_mem[0][key] * (read_mem[1][key]/mask_sum)) + \
                                                    (consolidate_mem[0][key] * (consolidate_mem[1][key]/mask_sum)) + \
                                                    (memorize_mem[0][key] * (memorize_mem[1][key]/mask_sum)) + \
                                                    (self.memories[self.steps_since_reset][key] * T.clamp(1-mask_sum, min=0))
                                                    )
                    #new_mem = tensordict.TensorDict(new_mem, batch_size=self.memories[self.steps_since_reset].batch_size)
                    #print((new_mem['m'] - self.memories[0]['m'])[0,:,0,0])
                    #print(new_mem['m'][0,:,0,0])
                    self.memories[self.steps_since_reset+1]=new_mem

                inaccuracies = T.sum(F.mse_loss(results, correct, reduction='none'), dim=-1) ## TODO: add hook so the inaccuracies can accurately represent the error of any supermodels.


                est_worth, self.hx_cx = self.worth_model(T.cat((x,correct), dim=-1), self.hx_cx)
                estimated_worth = T.sum(self.lstm_activation(est_worth), dim=-1)
                loss_estimated_worth = F.mse_loss(T.log(inaccuracies+1e-6), estimated_worth)


                routing_losses = T.mean(T.stack(routing_losses, dim=0))

                return self.deNaNed(results), routing_losses, loss_estimated_worth

        else:
            self.input=x
            self.step_index=0
            loops = x.size(-2)
            results = T.empty(x.size(), device=self.device)
            lru_hidden=[T.empty((x.size(0), 1, self.data_width*2), device=self.device)]*x.size(-2)
            for i in range(loops):




                self.steps_since_reset+=1

                result,log_inaccuracy, read_mem = self.read(x[:,i])
                if(self.autoscale): ## rescale to size of correct output
                      shift = T.mean(x[:,i], dim=-1, keepdim=True) - T.mean(result, dim=-1, keepdim=True)
                      scale = T.amax(x[:,i],dim=-1, keepdim=True) - T.amin(x[:,i],dim=-1, keepdim=True)
                      result = F.normalize(result-shift,dim=-1, p=float('inf'))*scale #result * (T.linalg.vector_norm(correct[:,i], ord=1)/T.linalg.vector_norm(result, ord=1))

                results[:,i]=result
                consolidate_mem = self.consolidate(5,2)

                memorize_mem = self.memorize(x[:,i], result, log_inaccuracy = log_inaccuracy)

                new_mem={}

                for key in self.memories[self.steps_since_reset].keys():
                    mask_sum = T.clamp(read_mem[1][key] + consolidate_mem[1][key] + memorize_mem[1][key], min=1e-6)

                    new_mem[key] = self.deNaNed((read_mem[0][key] * (read_mem[1][key]/mask_sum)) + \
                                                (consolidate_mem[0][key] * (consolidate_mem[1][key]/mask_sum)) + \
                                                (memorize_mem[0][key] * (memorize_mem[1][key]/mask_sum)) + \
                                                (self.memories[self.steps_since_reset][key] * T.clamp(1-mask_sum, min=0))
                                                )
                #new_mem = tensordict.TensorDict(new_mem, batch_size=self.memories[self.steps_since_reset].batch_size)
                self.memories[self.steps_since_reset+1]=new_mem

            return results






    @T.inference_mode()
    def mitm_route(self, x, output):

        # y_{i} = g((x - bv_{i}) @ m_{i}) + bw_{i}
        # y = sum( y_{i} * a_{i} )

        forward_vec = x.detach()
        backward_vec = output.detach().unsqueeze(-2)
        routing = [T.zeros((x.size(0), self.mem_len,1), device=self.device) for i in range(self.max_steps)]

        worth = T.zeros((x.size(0), self.mem_len,1), device=self.device)


        ## forward half is neural router. backward half is perfect routing.
        ## backwards goal = lerp(backward_vector, forward_vector, 1/(max_steps-step)) <-- this means backwards routing will move the same distance each step.
        for i in range(self.max_steps):
            if(i%2==1):
                #backward_vec_candidates =  T.linalg.solve(self.memories[-1]['m']+T.eye(self.data_width,device=self.device) * 1e-6, self.inv_activation(backward_vec-self.memories[-1]['bw']).unsqueeze(-2), left=False).squeeze(-2)

                lerp_forward = T.lerp(backward_vec.squeeze(-2), forward_vec, 1/(self.max_steps-i))


                matrix_results = self.activation(T.matmul((lerp_forward.unsqueeze(-2).expand(-1,self.mem_len,-1)-self.memories[self.steps_since_reset]['bv']).unsqueeze(-2), self.memories[self.steps_since_reset]['m'])).squeeze(-2) + self.memories[self.steps_since_reset]['bw'] + lerp_forward.unsqueeze(-2)
                backwards_route =T.linalg.lstsq(matrix_results.mT, backward_vec.mT).solution


                ## Theory: A high sparsity in the backwards route indicates a clear solution to the problem.
                ## If there is a clear solution to the problem, the number of steps needed to complete the solution
                ## should be low, so therefore be stopped early to prevent data degradation.

                #print(self.sparsity(backwards_route[:,:,0])[0])

                ## This isn't strictly neccessary, but it pushes the router to activate when forward vec is aprox. equal to bv

                softsign =(lambda x_: x_/(1+T.abs(x_)))
                w = ((F.cosine_similarity(forward_vec.unsqueeze(-2), self.memories[self.steps_since_reset]['bv'], dim=-1).unsqueeze(-1) + \
                      F.cosine_similarity(self.pos_encoding(self.steps_since_reset).unsqueeze(0).unsqueeze(0), self.memories[self.steps_since_reset]['t'], dim=-1).unsqueeze(-1)) + \
                      softsign(self.memories[self.steps_since_reset]['w']))
                #w=T.where(backwards_route.abs()>0.5, 1,-backwards_route)
                offset = (T.eye(self.mem_len,device=self.device).unsqueeze(0)-T.linalg.lstsq(matrix_results.mT, matrix_results.mT).solution)@w
                backwards_route +=offset

                #print("offset+route",self.sparsity(backwards_route[:,:,0])[0])
                #backwards_route *=0
                #backwards_route[:,1]=1
                routing[-i//2]=backwards_route

                '''
                matrix_sum = T.sum(backwards_route.unsqueeze(-1)*self.memories[-1]['m'], dim=-3)
                bv_sum = T.sum(backwards_route*self.memories[-1]['bv'],dim=-2,keepdim=True)
                bw_sum = T.sum(backwards_route*self.memories[-1]['bw'],dim=-2,keepdim=True)
                '''
                #matrix_results = self.activation(T.matmul((lerp_forward.unsqueeze(-2).expand(-1,self.mem_len,-1)-self.memories[self.steps_since_reset]['bv']).unsqueeze(-2), self.memories[self.steps_since_reset]['m'])).squeeze(-2) + self.memories[self.steps_since_reset]['bw']
                #print( (T.sum(backwards_route*matrix_results,dim=-2) - backward_vec[:,0])[0])

                backward_vec = lerp_forward.unsqueeze(-2)#F.normalize(T.sum(backward_vec_candidates*backwards_route, dim=-2, keepdim=True), dim=(-1,), p=float('inf'))
            else:
                attention_dat = T.cat((self.engram_info(),forward_vec.unsqueeze(-2).expand(-1,self.mem_len,-1)),dim=-1)
                routing[i//2]= self.attn_activation(T.sum(self.attention_model(attention_dat), dim=-1, keepdim=True))
                matrix_results = self.activation(T.matmul((forward_vec.unsqueeze(-2).expand(-1,self.mem_len,-1)-self.memories[self.steps_since_reset]['bv']).unsqueeze(-2), self.memories[self.steps_since_reset]['m'])).squeeze(-2) + self.memories[self.steps_since_reset]['bw']
                #matrix_sum = T.sum(routing[i//2].unsqueeze(-1)*self.memories[-1]['m'], dim=-3)
                #bv_sum = T.sum(routing[i//2]*self.memories[-1]['bv'],dim=-2,keepdim=True)
                #bw_sum = T.sum(routing[i//2]*self.memories[-1]['bw'],dim=-2,keepdim=True)
                ## I'd like to use residual connections, but they don't work with the backward routing.
                forward_vec = T.sum(matrix_results*routing[i//2], dim=-2) + forward_vec
                #forward_vec = F.normalize(self.activation(T.sum(T.bmm((forward_vec.unsqueeze(-2) -bv_sum), matrix_sum)) ) + bw_sum, dim=(-1,), p=float('inf')).squeeze(-2)




            #print("Backward", backward_vec[0])
        #self.debug_vectors[:,-1]= output
        return T.stack(routing, dim=-3)








    def read(self, x, correct=None):


        #self.memories[-1]['bv'] = self.memories[-1]['bv'] + T.rand(self.memories[-1]['bv'].size(), device=self.device)
        #print(self.memories[-1]['w'][0])

        result = [x]*(self.max_steps+1)

        # y_{i} = g((x - bv_{i}) @ m_{i}) + bw_{i}
        # y = sum( y_{i} * a_{i} )



        if(correct!=None):
            routing = self.mitm_route(x, correct).clone()
            routing_loss=T.zeros(1,device=self.device)
            for i in range(self.max_steps):

                matrix_results = self.activation(T.matmul((result[i].unsqueeze(-2).expand(-1,self.mem_len,-1)-self.memories[self.steps_since_reset]['bv']).unsqueeze(-2), self.memories[self.steps_since_reset]['m'])).squeeze(-2) + self.memories[self.steps_since_reset]['bw']

                result[i+1] = T.sum(routing[:,i]*matrix_results,dim=-2) + result[i]


                if self.training and i>=self.max_steps//2:
                    attention_dat = T.cat((self.engram_info(),result[i].unsqueeze(-2).expand(-1,self.mem_len,-1)),dim=-1)
                    routing_loss += F.mse_loss(routing[:,i],self.attn_activation(T.sum(self.attention_model(attention_dat),dim=-1)).unsqueeze(-1))


            inaccuracy = T.sum(F.mse_loss(result[-1],correct, reduction='none'), dim=-1, keepdim=True)
            d_worth = T.sum(routing, dim=1)*T.log(inaccuracy+1e-6).unsqueeze(-2).expand(-1,self.mem_len,-1)/self.max_steps

            read_mem_vals ={
                'm':0,
                'bv':0,
                'bw':0,
                'w':self.memories[self.steps_since_reset]['w'] - self.worth_mult*d_worth,
                't':0
                }

            read_mem_mask = {'m':0,'bv':0,'bw':0,'w':1,'t':0}



            return result[-1], routing_loss, (read_mem_vals, read_mem_mask)



        else:
            routing = [T.empty((x.size(0), self.mem_len,1))]*self.max_steps
            for i in range(self.max_steps):
                attention_dat = T.cat((self.engram_info(),result[i].unsqueeze(-2).expand(-1,self.mem_len,-1)),dim=-1)
                routing[i]=self.attn_activation(T.sum(self.attention_model(attention_dat),dim=-1)).unsqueeze(-1)

                matrix_results = self.activation(T.matmul((result[i].unsqueeze(-2).expand(-1,self.mem_len,-1)-self.memories[self.steps_since_reset]['bv']).unsqueeze(-2), self.memories[self.steps_since_reset]['m'])).squeeze(-2) + self.memories[self.steps_since_reset]['bw']
                result[i+1] = T.sum(routing[i]*matrix_results,dim=-2) + result[i]


            ## Unfortunately, there's no pretty way to incrementally predict the worth of each output using a transformer.
            ## Ideally, I would cache the internal state resulting from each step, but pytorch doesn't allow that.
            ## torchtune does, but that's for inference, and I'm not sure it's applicable to training.




            worth_est, self.hx_cx = self.worth_model(T.cat((x,result[-1]), dim=-1).unsqueeze(-2).detach(), self.hx_cx)
            worth_est = T.sum(self.lstm_activation(worth_est),dim=-1)
            d_worth =T.sum(T.stack(routing,dim=1), dim=1)*worth_est.unsqueeze(-2).expand(-1,self.mem_len,-1)/self.max_steps

            read_mem_vals={
                    'm':0,
                    'bv':0,
                    'bw':0,
                    'w': self.memories[self.steps_since_reset]['w']-self.worth_mult*d_worth,
                    't':0
                    }

            read_mem_mask = {'m':0,'bv':0,'bw':0,'w':1,'t':0}

        return result[-1], worth_est, (read_mem_vals, read_mem_mask)



    def memorize(self, x, y, log_inaccuracy=None): ## overly simplistic. Memorry consolidation is done elsewhere.

        x = F.normalize(x,dim=-1)#T.where(T.sum(T.abs(x),dim=-1, keepdim=True)>self.data_width, F.normalize(x,dim=-1), x)
        y = F.normalize(y,dim=-1)#T.where(T.sum(T.abs(y),dim=-1, keepdim=True)>self.data_width, F.normalize(y,dim=-1), y)


        new_bv = x
        new_bw = y



        #min_worth_idx = (T.rand(x.size(0),device=self.device)*self.mem_len).int()
        min_worth_idx = T.min(self.memories[self.steps_since_reset]['w'].squeeze(-1),dim=-1)[1]

        idx = T.arange(self.memories[self.steps_since_reset]['m'].size(0), device=self.device)

        memorize_mem_vals ={
                'm':T.eye(self.data_width, device=self.device),
                'bv':new_bv.unsqueeze(-2),
                'bw':new_bw.unsqueeze(-2),
                'w':-log_inaccuracy.unsqueeze(-2) if log_inaccuracy!=None else T.median(self.memories[self.steps_since_reset]['w'].squeeze(-1),dim=-1)[0].unsqueeze(-1).unsqueeze(-2),
                't':self.pos_encoding( self.steps_since_reset).to(self.device).unsqueeze(-2).expand(x.size(0),-1,-1)
                }


        mask = T.zeros((x.size(0), self.mem_len,1), device=self.device)
        mask[idx, min_worth_idx] = T.ones([1], device=self.device)

        memorize_mem_mask={'m':mask.unsqueeze(-1),'bv':mask,'bw':mask,'w':mask,'t':mask}

        return (memorize_mem_vals, memorize_mem_mask)

    def consolidate(self, num_k=5, loops=1):

        # finds the index of the engram with the most similarities.
        delta_b = (self.memories[self.steps_since_reset]['bw']-self.memories[self.steps_since_reset]['bv'])* T.sign(T.sum(T.abs(self.memories[self.steps_since_reset]['m']), dim=(-1,-2))).unsqueeze(-1)
        cos_sim = F.cosine_similarity(delta_b.unsqueeze(-2), delta_b.unsqueeze(-2).transpose(-2,-3),dim=-1)
        cos_sim += T.rand(cos_sim.size(),device=self.device)*0.002-0.001 ## inject a little bit of randomness.

        cos_sim = T.where(cos_sim.bool(), cos_sim,-1)-2*T.eye(self.mem_len, device=self.device).unsqueeze(0)

       #consolidate_mem_vals = map( lambda x: x.clone().detach(), self.memories[self.steps_since_reset])
        consolidate_mem_vals={
            'm':self.memories[self.steps_since_reset]['m'].clone().detach(),
            'bv':self.memories[self.steps_since_reset]['bv'].clone().detach(),
            'bw':self.memories[self.steps_since_reset]['bw'].clone().detach(),
            'w':0,#self.memories[self.steps_since_reset]['w'].clone().detach(),
            't':self.memories[self.steps_since_reset]['t'].clone().detach()
        }
        consolidate_mem_mask = {
            'm':T.zeros((self.memories[self.steps_since_reset]['m'].size(0), self.mem_len,1,1), device=self.device),
            'bv':T.zeros((self.memories[self.steps_since_reset]['bv'].size(0), self.mem_len,1), device=self.device),
            'bw':T.zeros((self.memories[self.steps_since_reset]['bw'].size(0), self.mem_len,1), device=self.device),
            'w':0,
            't':T.zeros((self.memories[self.steps_since_reset]['t'].size(0), self.mem_len,1), device=self.device)
            }


        for i in range(loops):
            most_similarities = T.max(T.max(F.relu(cos_sim),dim=-1)[0]/(1-T.mean(F.relu(cos_sim)+0.0001,dim=-1)), dim=-1)[1]
            idx = T.arange(self.memories[self.steps_since_reset]['m'].size(0), device=self.device)
            cos_sim += T.eye(self.mem_len, device=self.device).unsqueeze(0)*2 ## We want the index of the most similarities to be in the top k.
            topk = T.topk(cos_sim[idx,most_similarities,:],num_k,dim=-1).indices

            # generate new engram
            bv_diff = self.deNaNed(self.memories[self.steps_since_reset]['bv'][:,topk][:,0]-T.mean(self.memories[self.steps_since_reset]['bv'][:,topk],dim=-2,keepdim=True)[:,0])
            bw_diff = self.deNaNed(self.memories[self.steps_since_reset]['bw'][:,topk][:,0]-T.mean(self.memories[self.steps_since_reset]['bw'][:,topk],dim=-2,keepdim=True)[:,0])

            # lazy way to prevent non-full rank issues
            bv_diff += T.rand(bv_diff.size(), device=self.device) * 0.0001
            bw_diff += T.rand(bw_diff.size(), device=self.device) * 0.0001

            try:
                generated_matrix = T.linalg.lstsq(bv_diff, bw_diff).solution
            except Exception as e:
                print(e)
                print(bv_diff, bw_diff)
                exit()
            new_bv = T.mean(self.memories[self.steps_since_reset]['bv'][:,topk][:,0],dim=-2)
            new_bw = T.mean(self.memories[self.steps_since_reset]['bw'][:,topk][:,0],dim=-2)



            # remove nans
            generated_matrix = T.where(generated_matrix.isnan(), 0.0001, generated_matrix)
            new_bv = T.where(new_bv.isnan(), 0, new_bv)
            new_bw = T.where(new_bw.isnan(), 0, new_bw)


            # replace old engram

            consolidate_mem_vals['m'][idx,most_similarities] = generated_matrix
            consolidate_mem_vals['bv'][idx,most_similarities] = new_bv
            consolidate_mem_vals['bw'][idx,most_similarities] = new_bw
            consolidate_mem_vals['t'][idx,most_similarities] = self.pos_encoding( self.steps_since_reset).to(self.device)

            consolidate_mem_mask['m'][idx, most_similarities]+=1
            consolidate_mem_mask['bv'][idx, most_similarities]+=1
            consolidate_mem_mask['bw'][idx, most_similarities]+=1
            consolidate_mem_mask['t'][idx, most_similarities]+=1

            # set the similarity of previous consolidated engram to -1.
            cos_sim[idx,most_similarities]*=0
            cos_sim[idx,most_similarities]-=1
            cos_sim = T.clamp(cos_sim, min=-1, max=1)

        return (consolidate_mem_vals, consolidate_mem_mask)

# %%
import torch_optimizer as optim

sdapm=None
vae=None
loss=None
vae_opt=None
sdapm_opt=None
import gc
gc.collect()
T.cuda.empty_cache()
gc.collect()


batch_size=4
emb_size = 768
sdapm_emb_size = 60
epoch=0
iter=0
count=0
device='cuda'

checkpoints = list(filter(lambda x: x.startswith('TVAT'), os.listdir()))
if checkpoints==None or len(checkpoints)==0:
    vae = LanguageModel(emb_size, sdapm_emb_size, vocab_size, temporal_division=4, device=device)
    vae.tvat.encoder.expansion_offset=0
else:
    print("loading", sorted(checkpoints)[-1])
    vae = T.load(sorted(checkpoints)[-1], weights_only=False)
    vae.tvat.encoder.temporal_division=4

checkpoints = list(filter(lambda x: x.startswith('sdapm'), os.listdir()))
sdapm = SDAPM(sdapm_emb_size, mem_len=128, device=device, param_mem_mats=True)
if not ( checkpoints==None or len(checkpoints)==0):
    print("loading", sorted(checkpoints)[-1])
    sdapm.load_state_dict(T.load(sorted(checkpoints)[-1]) )


vae_opt = optim.DiffGrad(vae.parameters())
sdapm_opt = optim.DiffGrad(sdapm.parameters())

def softclamp(x, max):
  return max*((x/max)/(1+T.abs(x/max)))


#sdapm=T.compile(sdapm, backend='cudagraphs', dynamic=True)
#T._dynamo.config.capture_scalar_outputs = True
#vae=T.compile(vae, backend='cudagraphs')


vae_sdapm_opt = optim.DiffGrad((*vae.parameters(), *sdapm.parameters()), lr=5e-3)

max_grad_norm=100
def grad_norm(grad):
    global max_grad_norm
    if(T.any(grad.abs()>max_grad_norm)):
        return F.normalize(grad, dim=-1)*max_grad_norm
    return grad

padding_idx = tokenizer.token_to_id("`PAD`")


def max_norm(x, max):
  return T.where(T.sum(x)>max, F.normalize(x, p=1, dim=-1)*max, x)



for p in sdapm.parameters():
    p.register_hook(grad_norm)
for p in vae.parameters():
    p.register_hook(grad_norm)

import time

print(sdapm.initial_mem_mats[0,7:,7:])
sdapm_loss=T.zeros(1)
vae_loss = T.zeros(1)

while True:

  count = count+batch_size % (len(dataset)-batch_size)
  data_batch = T.nn.utils.rnn.pad_sequence([T.tensor(data.ids) for data in dataset[count:count+batch_size]], batch_first=True, padding_value=tokenizer.token_to_id("`PAD`"), padding_side='right').int().to(device)[:,:128]


  if(( (iter<00))):
    print("vae_only")

    reconstruction, len_loss = vae(data_batch)
    loss = F.cross_entropy(reconstruction.transpose(-1,-2), data_batch.long(), ignore_index = padding_idx) + vae.kl/emb_size/batch_size + T.mean(len_loss)
    loss.backward()
    vae_opt.step()
    if(iter%100==0):
      print("---===+++ EXAMPLE RECONSTRUCTION +++===---\n"+tokenizer.decode(T.argmax(reconstruction[0], dim=-1).tolist(), skip_special_tokens=False)+"\n---===+++#############+++===---")
  elif(True or iter%100>=66):
    print("sdapm_only+vae")

    embedded, len_loss, _ = vae.embed(data_batch[:,:-1])


    #print(T.histc(T.floor(sections)[:,-1])sizes
    z = sdapm(embedded)
    with T.no_grad():
      _, sizes = vae.tvat.generate_mask(embedded.detach(), data_batch.size(-2), return_sizes=True)
      correct_results=[None]*batch_size
      for i in range(batch_size):
        correct_results[i] = data_batch[i,sizes[i][0]:]
      correct_result= T.nn.utils.rnn.pad_sequence(correct_results, batch_first=True, padding_value=tokenizer.token_to_id("`PAD`"), padding_side='right').int().to(device).detach()
      correct_result = T.cat((correct_result, T.full((batch_size, data_batch.size(-1)-correct_result.size(-1)),tokenizer.token_to_id("`PAD`"), device=device)), dim=-1)
    #ae.tvat.generate_mask(z, data_batch.size(-2))

    prediction= vae.exbed(z, data_batch.size(-1), correct=vae.embedding(correct_result))
    loss = F.cross_entropy(prediction.transpose(-1,-2), correct_result.long(), ignore_index = padding_idx) +T.mean(len_loss) + vae.kl/emb_size/batch_size



    loss.backward()
    #sdapm_opt.step()
    vae_sdapm_opt.step()
    #vae_opt.step()
    if(iter%100==99):
      print("---===+++ EXAMPLE RESULT +++===---\n"+tokenizer.decode(T.argmax(prediction[0], dim=-1).tolist(), skip_special_tokens=False)+"\n---===+++################+++===---")

  else:
    if(iter>100):
      #print("sdapm_only")
      enc_data = vae.embed(data_batch)[0].detach()
      #print(T.max(T.abs(enc_data)))
      prediction, r_loss, w_loss = sdapm(enc_data[:,:-1], enc_data[:,1:])

      #print(T.max(T.abs(prediction)))
      print(r_loss.item(), w_loss.item())
      sdapm_loss = F.mse_loss(prediction, enc_data[:,1:]) + softclamp(r_loss,1000) + softclamp(w_loss, 100)
      sdapm_loss.backward()
      sdapm_opt.step()

    reconstruction, len_loss = vae(data_batch)
    vae_loss = F.cross_entropy(reconstruction.transpose(-1,-2), data_batch.long(), ignore_index = padding_idx) + vae.kl/emb_size/batch_size + T.mean(len_loss)
    vae_loss.backward()
    vae_opt.step()
    if(iter%100==0):
      print("---===+++ EXAMPLE RECONSTRUCTION +++===---\n"+tokenizer.decode(T.argmax(reconstruction[0], dim=-1).tolist(), skip_special_tokens=False)+"\n---===+++#############+++===---")


    #print(tokenizer.decode(T.argmax(prediction[0], dim=-1).tolist()))

  iter+=1
  #vae_opt.zero_grad(set_to_none=True)
  #sdapm_opt.zero_grad(set_to_none=True)
  vae_sdapm_opt.zero_grad(set_to_none=True)

  if iter%30==29:
    T.cuda.empty_cache()
  gc.collect()
  print("EPOCH "+str(math.floor(iter/len(dataset))) +"\tLOSS_VAE: "+ str(vae_loss.item())+"\tLOSS_SDAPM: "+ str(loss.item()))
  vae.tvat.decoder.b_mix.set_probs(0.1**(1/((iter+1500000)*0.003))) ## slowly converges to 1, decreasing the influence of the input skip layer on the decoder.

  if(T.any(T.isnan(sdapm.initial_mem_mats)) or T.any(T.isnan(sdapm.initial_bv)) or T.any(T.isnan(sdapm.initial_bw))):
    checkpoints = list(filter(lambda x: x.startswith('sdapm'), os.listdir()))
    print("loading", sorted(checkpoints)[-1])
    sdapm.load_state_dict(T.load(sorted(checkpoints)[-1]) )

  if(iter%500==0):
    print("saving...")
    current_time = time.time()
    T.save(sdapm.state_dict(), "sdapm_"+str(int(current_time))+".pt")
    T.save(vae, "TVAT_"+str(int(current_time))+".pt")
# Out:
# loading TVAT_1752865178.pt
# loading sdapm_1752865178.pt
# tensor([[ 0.0286,  0.1285, -0.1284,  ...,  0.0129, -0.0653, -0.0211],
#         [-0.0389,  0.1149,  0.0314,  ...,  0.0205, -0.0044, -0.0640],
#         [-0.0198,  0.0047, -0.1036,  ..., -0.0749, -0.1251, -0.0753],
#         ...,
#         [-0.0977,  0.0415, -0.0689,  ..., -0.0153, -0.1933, -0.0215],
#         [-0.0306, -0.0017, -0.0076,  ...,  0.0641, -0.0439, -0.0259],
#         [ 0.2209,  0.2566,  0.2286,  ...,  0.1570,  0.0913,  0.3188]],
#        device='cuda:0', grad_fn=<SliceBackward0>)
# sdapm_only+vae
# /tmp/ipython-input-4-3066388545.py:121: UserWarning: index_reduce() is in beta and the API may change at any time. (Triggered internally at /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1323.)
#   densified_z[i,T.floor(sections).int()] = T.index_reduce(z, dim=1, index=T.floor(sections[i]).int(), source=z, reduce='mean')
# Streaming output truncated to the last 5000 lines.
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.549012184143066
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.587272644042969
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.50847053527832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.364312171936035
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.192941665649414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.776065826416016
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.602923393249512
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.161172866821289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.056880950927734
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.377476692199707
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.124530792236328
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.317265510559082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.117131233215332
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.665565490722656
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.86704158782959
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.788851737976074
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.478437423706055
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.917162895202637
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.959941864013672
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.53917407989502
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.4743013381958
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.065956115722656
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.247419357299805
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.093167304992676
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.72932243347168
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.188340187072754
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.748964309692383
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.982034683227539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.997369766235352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.66552734375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.53492546081543
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.063813209533691
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.300406455993652
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.675479888916016
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.749554634094238
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.396448135375977
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.848672866821289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.924860000610352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.685041427612305
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.292539596557617
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.394187927246094
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.888761520385742
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.661691665649414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.571561813354492
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.374242782592773
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.346700668334961
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.054367065429688
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.557832717895508
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.55078125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.929803848266602
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.021998405456543
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.497786521911621
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.731931686401367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.291412353515625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.700100898742676
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.189888954162598
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.097530364990234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.344898223876953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.2277250289917
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.718557357788086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.851713180541992
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.565950393676758
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.353231430053711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.966426849365234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.998706817626953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.38646125793457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.897455215454102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.72109603881836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.906816482543945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.353998184204102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.426010131835938
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.506808280944824
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
#   '       arent
#  `STOP` cheer                 `STOP`     put         ed
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.780564308166504
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.352115631103516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.399659156799316
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.849539756774902
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.296079635620117
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.456686973571777
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.46949291229248
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.027236938476562
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.067999839782715
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.7433443069458
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.22371768951416
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.902640342712402
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.891963958740234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.695154190063477
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.613729476928711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.158470153808594
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.619340896606445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.472036361694336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.501729965209961
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.287034034729004
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.12105941772461
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.743404388427734
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.177774429321289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.690979957580566
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.33633041381836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.073110580444336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.148077011108398
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.92792797088623
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.43345832824707
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.060090065002441
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.056720733642578
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.475109100341797
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.797962188720703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.393949508666992
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.9268798828125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.767998695373535
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.363279342651367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.728523254394531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.190839767456055
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.896997451782227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.696734428405762
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.072916030883789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.797086715698242
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.361740112304688
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.866033554077148
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.376638412475586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.966742515563965
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.787419319152832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.723527908325195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.061939239501953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.112349510192871
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.62657642364502
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.452788352966309
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.499565124511719
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.734474182128906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.939233779907227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.743526458740234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.295467376708984
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.093658447265625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.741580963134766
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.771194458007812
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.957023620605469
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.329208374023438
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.696832656860352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.067537307739258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.41342544555664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.037696838378906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.119133949279785
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.547477722167969
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.16561508178711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.411142349243164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.47142219543457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.66135311126709
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.517858505249023
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.454818725585938
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.192035675048828
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.08822250366211
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.33201789855957
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.420478820800781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.001152992248535
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.622781753540039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.663749694824219
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.938587188720703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.1679105758667
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.959356307983398
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.76220703125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.82577896118164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.31181526184082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.766162872314453
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.053281784057617
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.463056564331055
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.171092987060547
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.888570785522461
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.172371864318848
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.246576309204102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.98973560333252
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.796615600585938
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.712972640991211
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.98238754272461
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.35515022277832
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
# did         bear hast     worth       ? `GO` telegraph                             somehow chu
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.265250205993652
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.543352127075195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.460210800170898
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.76822566986084
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.435819625854492
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.141887664794922
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.609111785888672
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.966072082519531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.340503692626953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.767195701599121
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.146540641784668
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.192934036254883
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.736686706542969
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.115485191345215
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.799338340759277
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.606550216674805
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.050493240356445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.510089874267578
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.257110595703125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.94525146484375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.334318161010742
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.701807022094727
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.146530151367188
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.803596496582031
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.84321117401123
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.831544876098633
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.319491386413574
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.560110092163086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.989950180053711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.51688003540039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.691965103149414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.218585968017578
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.54442024230957
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.499629020690918
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.650625228881836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.905031204223633
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.03018569946289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.788467407226562
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.335893630981445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.936065673828125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.877315521240234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.573199272155762
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.750960350036621
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.01554012298584
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.834907531738281
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.05702018737793
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.84302806854248
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.130542755126953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.911805152893066
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.115386009216309
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.154019355773926
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.965581893920898
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.046152114868164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.804805755615234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.688680648803711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.314950942993164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.006807327270508
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.673579216003418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.546308517456055
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.657014846801758
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.519054412841797
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.427499771118164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.244205474853516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.624532699584961
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.294809341430664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.488359451293945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.617597579956055
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.170053482055664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.801078796386719
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.49759292602539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.96102237701416
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.476329803466797
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.084879875183105
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.835977554321289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.250786781311035
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.452018737792969
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.65310287475586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.048711776733398
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.292112350463867
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.259132385253906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.044412612915039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.720489501953125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.088293075561523
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.687114715576172
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.3137845993042
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.132652282714844
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.692330360412598
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.170703887939453
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.338769912719727
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.59807014465332
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.408283233642578
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.747581481933594
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.618556022644043
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.85302734375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.148983001708984
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.018796920776367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.058698654174805
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.427167892456055
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.538999557495117
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.56631088256836
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
# sir     down                                             each
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.880045890808105
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.856698036193848
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.780027389526367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.235674858093262
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.691190719604492
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.578969955444336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.36634635925293
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.410747528076172
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.163691520690918
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.940757751464844
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.220985412597656
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.992513656616211
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.673137664794922
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.763359069824219
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.921897888183594
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.934825897216797
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.533212661743164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.556848526000977
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.502918243408203
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.611381530761719
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.950066566467285
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.823704719543457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.537809371948242
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.270374298095703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.496564865112305
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.052837371826172
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.263496398925781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.01702880859375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.162820816040039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.819808959960938
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.840993881225586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.856109619140625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.34609603881836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.999150276184082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.95817756652832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.671051025390625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.618528366088867
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.724498748779297
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.500863075256348
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.480034828186035
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.52775764465332
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.243017196655273
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.077596664428711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.144550323486328
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.62553596496582
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.48937702178955
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.1326904296875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.57802677154541
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.933238983154297
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.347917556762695
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.188333511352539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.164440155029297
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.288812637329102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.226383209228516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.873418807983398
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.574946403503418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.223127365112305
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.160640716552734
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.699591636657715
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.986560821533203
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.943909645080566
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.474250793457031
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.008796691894531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.707229614257812
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.070741653442383
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.401893615722656
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.995319366455078
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.36395263671875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.814916610717773
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.26423454284668
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.432746887207031
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.38715934753418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.451462745666504
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.935676574707031
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.977866172790527
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.67483139038086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.320964813232422
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.701130867004395
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.115750312805176
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.089075088500977
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.169506072998047
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.751665115356445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.475412368774414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.92701530456543
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.579111099243164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.25809097290039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.661195755004883
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.364683151245117
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.218488693237305
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.721582412719727
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.962335586547852
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.710721969604492
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.447540283203125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.11380672454834
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.434388160705566
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.968854904174805
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.33309555053711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.08456039428711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.509334564208984
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.862937927246094
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
#                   .             friends about friends   son lad the       see action . .
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.605698585510254
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.160789489746094
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.903316497802734
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.799100875854492
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.130199432373047
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.659337997436523
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.700654983520508
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.338204383850098
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.368143081665039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.835552215576172
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.142001152038574
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.094714164733887
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.471485137939453
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.681358337402344
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.586690902709961
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.261380195617676
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.253737449645996
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.151411056518555
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.677803993225098
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.886356353759766
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.448432922363281
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.158647537231445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.474710464477539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.288042068481445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.002220153808594
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.18960952758789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.415790557861328
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.89324951171875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.797192573547363
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.013008117675781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.723997116088867
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.524806022644043
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.74827766418457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.062124252319336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.681364059448242
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.971220016479492
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.780531883239746
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.294475555419922
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.311214447021484
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.655678749084473
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.347766876220703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.320072174072266
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 14.149276733398438
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 14.359964370727539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.721603393554688
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.763391494750977
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 14.488839149475098
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.743820190429688
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 14.4335298538208
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.918033599853516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 14.429533958435059
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.374608039855957
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 15.76970100402832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 13.749345779418945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.51158332824707
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.672333717346191
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.835790634155273
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.499460220336914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.564460754394531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.584794998168945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.030902862548828
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.458552360534668
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.121938705444336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.173870086669922
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.169256210327148
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.44314956665039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.80797004699707
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.96531867980957
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.383609771728516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.033035278320312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.862876892089844
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.04892635345459
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.431388854980469
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.519733428955078
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.11276626586914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.98748779296875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.38355827331543
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.853729248046875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.83220100402832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.613579750061035
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.285055160522461
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.195667266845703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.593880653381348
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.477534294128418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.280097961425781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.106393814086914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.412181854248047
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.248366355895996
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.982433319091797
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.122705459594727
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.934296607971191
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.033329963684082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.441215515136719
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.844003677368164
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.183916091918945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.722352981567383
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.355419158935547
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.295795440673828
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.532791137695312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.627473831176758
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
#                 i     throw need   the       have grace   govern   right   my nourish           pake
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.799041748046875
# saving...
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 7.552643775939941
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.065110206604004
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.084228515625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.614278793334961
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.199636459350586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.959785461425781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.01638412475586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.642066955566406
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.261285781860352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.393863677978516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.486261367797852
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.4539213180542
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.056047439575195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.503463745117188
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.87116813659668
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.3604154586792
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.997958183288574
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.776079177856445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.746405601501465
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.556265830993652
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.892498016357422
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.529596328735352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.94532585144043
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.831155776977539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.204578399658203
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.654619216918945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.670732498168945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.512807846069336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.085122108459473
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.222162246704102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.426788330078125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.929441452026367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.75643539428711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.496192932128906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.531883239746094
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.497631072998047
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.041641235351562
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.206136703491211
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.316725730895996
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.196266174316406
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.531454086303711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.70567512512207
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.0289888381958
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.727546691894531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.006406784057617
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.653676986694336
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.388093948364258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.879013061523438
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 7.63606071472168
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.965841293334961
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.672788619995117
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.922430038452148
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.88364028930664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.45545768737793
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.27143669128418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.66794204711914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.962079048156738
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.908516883850098
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.395998001098633
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.156339645385742
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.249269485473633
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.818815231323242
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.648768424987793
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.364592552185059
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.778152465820312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.623730659484863
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.766118049621582
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.641120910644531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.976337432861328
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.360593795776367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.470107078552246
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.997550964355469
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.090136528015137
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.531194686889648
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.707595825195312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.84989070892334
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.08275032043457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.244644165039062
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.009366989135742
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.891813278198242
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.324785232543945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.235366821289062
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.216177940368652
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.704536437988281
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.49620246887207
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.311710357666016
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.469330787658691
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.639203071594238
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.344456672668457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.938323974609375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.940744400024414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.205102920532227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.389348030090332
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.703386306762695
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.478854179382324
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.904635429382324
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.132667541503906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.716215133666992
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.829560279846191
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
# worthy       dark     signal           mike         dark that mike     child   .     hanging
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.447112083435059
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.70000171661377
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.117198944091797
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.319978713989258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.794318199157715
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.233963012695312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.285102844238281
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.45361614227295
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.750490188598633
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.023965835571289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.724417686462402
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.266590118408203
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.21746826171875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.526092529296875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.940868377685547
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.660720825195312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.591453552246094
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.637918472290039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.6519775390625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.62452507019043
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.592448234558105
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.135881423950195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.952276229858398
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.747401237487793
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.895523071289062
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.863324165344238
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.218450546264648
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.515287399291992
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.449373245239258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.820295333862305
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.649762153625488
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.843717575073242
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.9819974899292
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.81110954284668
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.509329795837402
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.707374572753906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.150947570800781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.558212280273438
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.956600189208984
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.121538162231445
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.444677352905273
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.585399627685547
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.992721557617188
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.12534236907959
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.659280776977539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.424768447875977
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.87028980255127
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.039170265197754
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.003725051879883
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.302705764770508
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.95671558380127
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.247865676879883
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.060155868530273
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.392541885375977
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.213001251220703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.925699234008789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.712865829467773
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.716068267822266
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.924802780151367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.499078750610352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.253814697265625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.079211235046387
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.551889419555664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.883455276489258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.016923904418945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.109962463378906
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.46784496307373
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.764183044433594
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.408348083496094
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.787790298461914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.783248901367188
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.788491249084473
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.589607238769531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.767419815063477
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.935354232788086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.031021118164062
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.996442794799805
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.267022132873535
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.462686538696289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.191040992736816
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.591136932373047
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.509572982788086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.527252197265625
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.084329605102539
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.494155883789062
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.221722602844238
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.181306838989258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.080309867858887
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.244288444519043
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.636402130126953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.532026290893555
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.687162399291992
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.280351638793945
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.08713436126709
# sdapm_only+vae
# ...
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.683786392211914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.564504623413086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.645390510559082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.796077728271484
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.796233177185059
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.284154891967773
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.524063110351562
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.806550979614258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.799445152282715
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.758188247680664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.988685607910156
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.380141258239746
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.386423110961914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.81063461303711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.61294937133789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.73375129699707
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.186399459838867
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.647692680358887
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.564955711364746
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.751094818115234
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.141045570373535
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.288461685180664
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.930309295654297
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.161941528320312
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.305922508239746
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.613314628601074
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
# daughter ' ! !   easter why   oving                         ca
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.278389930725098
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.087985038757324
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.927000999450684
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.282296180725098
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.87211799621582
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.078585624694824
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.469120025634766
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.910329818725586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.89390754699707
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.578084945678711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.210531234741211
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 12.677008628845215
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.982634544372559
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.718141555786133
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.024187088012695
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.929752349853516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.29318618774414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.028722763061523
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.897024154663086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.621905326843262
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.254033088684082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.009521484375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.017868041992188
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.700265884399414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.560457229614258
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.395085334777832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.237709045410156
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.140668869018555
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.033524513244629
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.716403007507324
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.858410835266113
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.122135162353516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.949028015136719
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.256296157836914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.32692813873291
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.679444313049316
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.756305694580078
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.663060188293457
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.132837295532227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.529635429382324
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.358245849609375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.873151779174805
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.583480834960938
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.89889907836914
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.7354097366333
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.326705932617188
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.950886726379395
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.224372863769531
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.792377471923828
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.697145462036133
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.377792358398438
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.594841003417969
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.009002685546875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.21986198425293
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.956521034240723
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.970980644226074
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.035086631774902
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.660781860351562
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.053464889526367
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.554451942443848
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.823565483093262
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.341772079467773
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.319690704345703
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.314903259277344
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.722477912902832
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.389782905578613
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.792667388916016
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.116863250732422
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.260631561279297
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.373283386230469
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.594472885131836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.863561630249023
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.328302383422852
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.440445899963379
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.886603355407715
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.812063217163086
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.221111297607422
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.257052421569824
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.528844833374023
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.747838973999023
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.998557090759277
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.938226699829102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.910074234008789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.443557739257812
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.222587585449219
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.101930618286133
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.352434158325195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.9266357421875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.584465026855469
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.238530158996582
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.714624404907227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.538373947143555
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.194507598876953
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.417383193969727
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.22265338897705
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.433538436889648
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.386560440063477
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.609399795532227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.679549217224121
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.690258026123047
# sdapm_only+vae
# ---===+++ EXAMPLE RESULT +++===---
# is     violent   alone   us                               be is     cant
# ---===+++################+++===---
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.596004486083984
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.312202453613281
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.230430603027344
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.512674331665039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.55608081817627
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.71430778503418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.94510269165039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.582598686218262
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.366195678710938
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.245819091796875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.482990264892578
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.53643798828125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.055996894836426
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.607780456542969
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.203274726867676
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.153314590454102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.619232177734375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.705065727233887
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.779190063476562
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.878280639648438
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.227846145629883
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.176289558410645
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.569411277770996
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.011011123657227
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.573368072509766
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.716148376464844
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.230804443359375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.51445198059082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.804189682006836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.975055694580078
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.358945846557617
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.141505241394043
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.27484130859375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.355783462524414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.797809600830078
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.342733383178711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.029727935791016
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.218740463256836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.28089427947998
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.604804992675781
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.157953262329102
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.17724609375
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.750417709350586
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.038856506347656
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.597051620483398
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.08985424041748
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.7489595413208
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.951554298400879
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.143839836120605
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.80799388885498
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.585222244262695
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.279825210571289
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.872720718383789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.668756484985352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.248854637145996
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.877079010009766
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.114313125610352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.162859916687012
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.184879302978516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.31928825378418
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.268937110900879
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.05937385559082
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.510807037353516
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.257301330566406
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 11.808669090270996
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.938483238220215
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.27138900756836
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.672386169433594
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.277727127075195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.981500625610352
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.990628242492676
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.778350830078125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.907205581665039
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.766481399536133
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.802206039428711
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 8.901580810546875
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.084856033325195
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.083769798278809
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.880743980407715
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.852313995361328
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.254932403564453
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.41729736328125
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.949466705322266
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.91086196899414
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.71402359008789
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 9.926911354064941
# sdapm_only+vae
# EPOCH 0	LOSS_VAE: 0.0	LOSS_SDAPM: 10.163984298706055
# loading sdapm_1752905470.pt
# sdapm_only+vae
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-7-3747396067.py in <cell line: 0>()
#     100     z = sdapm(embedded)
#     101     with T.no_grad():
# --> 102       _, sizes = vae.tvat.generate_mask(embedded.detach(), data_batch.size(-2), return_sizes=True)
#     103       correct_results=[None]*batch_size
#     104       for i in range(batch_size):
#
# /tmp/ipython-input-4-3066388545.py in generate_mask(self, z, length, return_sizes)
#     173       sizes=[None]*z.size(0)
#     174       for i in range(z.size(0)): ###AAAAHHHH I HATE THISSS
# --> 175         sizes[i] = T.histc(idxs[i].float(), T.clamp(T.amax(idxs[i]),min=1)   ).int().tolist()
#     176
#     177         xpos = 0
#
# RuntimeError: amax(): Expected reduction dim to be specified for input.numel() == 0. Specify the reduction dim with the 'dim' argument.
